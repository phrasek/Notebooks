# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
from tabulate import tabulate
# %matplotlib inline
# case 1, each unit has EFOR = 1-CF
# case 2, each unit has no FOR, weather based generation profile
# case 3, each unit has FOR and weather based generation profile
# a conventional generator unit, a coal fired steam turbine, is included as 'con'
id = "avgcf"
num_sims = 100

with open(f"{num_sims}avg_{id}.p", "rb") as infile:
    results = pickle.load(infile)

    i=1
    df1 = results[0]
    print(f'Case 1, each unit has EFOR = 1-CF')
    print(tabulate(df1[['wind','solar','total_gen','net_power']].describe(percentiles=[.25,.5,.75,.9]),headers="keys",tablefmt='fancy_grid'))
    print(
        f'Number of times where demand exceeded supply: {df1[df1["net_power"] < 0].net_power.count()}'
    )
# Out:
# Case 1, each unit has EFOR = 1-CF
# ╒═══════╤════════════╤════════════╤═════════════╤═════════════╕
# │       │       wind │      solar │   total_gen │   net_power │
# ╞═══════╪════════════╪════════════╪═════════════╪═════════════╡
# │ count │ 8760       │ 8760       │  8760       │   8760      │
# ├───────┼────────────┼────────────┼─────────────┼─────────────┤
# │ mean  │   52.0259  │   31.3686  │   232.194   │    132.303  │
# ├───────┼────────────┼────────────┼─────────────┼─────────────┤
# │ std   │    6.93964 │    5.27066 │     9.24824 │     30.9279 │
# ├───────┼────────────┼────────────┼─────────────┼─────────────┤
# │ min   │   29.3663  │   14.8634  │   200.257   │     15.8454 │
# ├───────┼────────────┼────────────┼─────────────┼─────────────┤
# │ 25%   │   46.9861  │   27.2495  │   225.925   │    117.252  │
# ├───────┼────────────┼────────────┼─────────────┼─────────────┤
# │ 50%   │   51.3911  │   30.9653  │   232.137   │    140.966  │
# ├───────┼────────────┼────────────┼─────────────┼─────────────┤
# │ 75%   │   57.2644  │   34.6812  │   238.486   │    154.122  │
# ├───────┼────────────┼────────────┼─────────────┼─────────────┤
# │ 90%   │   61.6693  │   38.397   │   244.106   │    163.895  │
# ├───────┼────────────┼────────────┼─────────────┼─────────────┤
# │ max   │   77.8208  │   52.0218  │   263.187   │    193.48   │
# ╘═══════╧════════════╧════════════╧═════════════╧═════════════╛
# Number of times where demand exceeded supply: 0

# %%
    df1.plot(subplots=True, kind="kde", ind=8760, title=f"Case {i} Density Plot")
    df1.plot(subplots=True,title=f"Case {i} Annual Mean")
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
    i=2
    df2 = results[1]
    print(f'Case {i}, each unit has no FOR, weather based generation profile')
    print(tabulate(df2[['wind','solar','total_gen','net_power']].describe(percentiles=[.25,.5,.75,.9]),headers="keys",tablefmt='fancy_grid'))
    print(
        f'Number of times where demand exceeded supply: {df2[df2["net_power"] < 0].net_power.count()}'
    )
# Out:
# Case 2, each unit has no FOR, weather based generation profile
# ╒═══════╤═══════════╤═══════════╤═════════════╤═════════════╕
# │       │      wind │     solar │   total_gen │   net_power │
# ╞═══════╪═══════════╪═══════════╪═════════════╪═════════════╡
# │ count │ 8760      │ 8760      │   8760      │   8760      │
# ├───────┼───────────┼───────────┼─────────────┼─────────────┤
# │ mean  │   41.723  │   34.2479 │    224.771  │    -23.9198 │
# ├───────┼───────────┼───────────┼─────────────┼─────────────┤
# │ std   │   49.0166 │   40.4793 │     60.5204 │     70.0166 │
# ├───────┼───────────┼───────────┼─────────────┼─────────────┤
# │ min   │    0      │    0      │    136.515  │   -187.452  │
# ├───────┼───────────┼───────────┼─────────────┼─────────────┤
# │ 25%   │    2.1    │    0      │    166.788  │    -76.3849 │
# ├───────┼───────────┼───────────┼─────────────┼─────────────┤
# │ 50%   │   17.45   │    0      │    226.542  │    -33.7705 │
# ├───────┼───────────┼───────────┼─────────────┼─────────────┤
# │ 75%   │   72.325  │   81.5    │    262.175  │     22.9473 │
# ├───────┼───────────┼───────────┼─────────────┼─────────────┤
# │ 90%   │  131.7    │   92.3    │    298.203  │     71.306  │
# ├───────┼───────────┼───────────┼─────────────┼─────────────┤
# │ max   │  148.3    │  115.2    │    403.665  │    173.938  │
# ╘═══════╧═══════════╧═══════════╧═════════════╧═════════════╛
# Number of times where demand exceeded supply: 5637

# %%
    df2.plot(subplots=True, kind="kde", ind=8760, title=f"Case {i} Density Plot")
    df2.plot(subplots=True,title=f"Case {i} Annual Mean")
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
    i=3
    df3 = results[2]
    print(f'Case {i}, each unit has FOR and weather based generation profile')
    print(tabulate(df3[['wind','solar','total_gen','net_power']].describe(percentiles=[.25,.5,.75,.9]),headers="keys",tablefmt='fancy_grid'))
    print(
        f'Number of times where demand exceeded supply: {df3[df3["net_power"] < 0].net_power.count()}'
    )
# Out:
# Case 3, each unit has FOR and weather based generation profile
# ╒═══════╤════════════╤═══════════╤═════════════╤═════════════╕
# │       │       wind │     solar │   total_gen │   net_power │
# ╞═══════╪════════════╪═══════════╪═════════════╪═════════════╡
# │ count │ 8760       │ 8760      │   8760      │   8760      │
# ├───────┼────────────┼───────────┼─────────────┼─────────────┤
# │ mean  │   38.376   │   31.8744 │    190.3    │     90.4095 │
# ├───────┼────────────┼───────────┼─────────────┼─────────────┤
# │ std   │   45.1257  │   37.7027 │     55.9232 │     65.8938 │
# ├───────┼────────────┼───────────┼─────────────┼─────────────┤
# │ min   │    0       │    0      │    110.244  │    -67.4811 │
# ├───────┼────────────┼───────────┼─────────────┼─────────────┤
# │ 25%   │    1.93366 │    0      │    136.453  │     41.8023 │
# ├───────┼────────────┼───────────┼─────────────┼─────────────┤
# │ 50%   │   16.0267  │    0      │    191.879  │     80.9868 │
# ├───────┼────────────┼───────────┼─────────────┼─────────────┤
# │ 75%   │   66.0371  │   75.7178 │    224.569  │    135.201  │
# ├───────┼────────────┼───────────┼─────────────┼─────────────┤
# │ 90%   │  120.107   │   85.9248 │    258.935  │    179.641  │
# ├───────┼────────────┼───────────┼─────────────┼─────────────┤
# │ max   │  144.187   │  107.51   │    361.368  │    278.781  │
# ╘═══════╧════════════╧═══════════╧═════════════╧═════════════╛
# Number of times where demand exceeded supply: 594

# %%
    df3.plot(subplots=True, kind="kde", ind=8760, title=f"Case {i} Density Plot")
    df3.plot(subplots=True,title=f"Case {i} Annual Mean")
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
totals = pd.DataFrame({
    'solar':[x['solar'].sum() for x in results],
    'wind':[x['wind'].sum() for x in results],
    'solar_wind':[x['solar'].sum() + x['wind'].sum() for x in results],
},index=['case 1','case 2','case 3'])
print('Total annual generation')
print(tabulate(totals,headers="keys",tablefmt='fancy_grid'))
# Out:
# Total annual generation
# ╒════════╤═════════╤════════╤══════════════╕
# │        │   solar │   wind │   solar_wind │
# ╞════════╪═════════╪════════╪══════════════╡
# │ case 1 │  274789 │ 455746 │       730535 │
# ├────────┼─────────┼────────┼──────────────┤
# │ case 2 │  300012 │ 365494 │       665505 │
# ├────────┼─────────┼────────┼──────────────┤
# │ case 3 │  279220 │ 336174 │       615394 │
# ╘════════╧═════════╧════════╧══════════════╛
